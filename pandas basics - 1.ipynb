# %% [markdown]
# # importing  table file

# %%
import  pandas as pd
orders = pd.read_table("http://bit.ly/chiporder")
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# # giving  columns a name

# %%
user_cols =["user_id","age","gender","occupation","zip code"]
user = pd.read_table("http://bit.ly/movieusers",sep = "|",header = None, names = user_cols)
user.head()
# Out:
#    user_id  age gender  occupation zip code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %% [markdown]
# # way of opening specific columns and creatin new column in data frame

# %%
ufo = pd.read_csv("http://bit.ly/uforeports")
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
type(ufo["City"])
# Out:
# pandas.core.series.Series

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
ufo["location"] =ufo.City+","+ufo.State
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time                 location
# 0        6/1/1930 22:00                Ithaca,NY
# 1       6/30/1930 20:00           Willingboro,NJ
# ...

# %% [markdown]
# # rename  the columns name

# %%
ufo.rename(columns={'Colors Reported':'Colour_Reported'}, inplace = True)
ufo.columns
# Out:
# Index(['Area', 'Colour_Reported', 'Shape Reported', 'State', 'Time',
#        'location'],
#       dtype='object')

# %%
user_colls = ["city",'colour report','shape report',"statee","timee","location"]
ufo.columns = user_colls
ufo
# Out:
#                        city colour report shape report statee  \
# 0                    Ithaca           NaN     TRIANGLE     NY
# 1               Willingboro           NaN        OTHER     NJ
# 2                   Holyoke           NaN         OVAL     CO
# 3                   Abilene           NaN         DISK     KS
# 4      New York Worlds Fair           NaN        LIGHT     NY
# ...                     ...           ...          ...    ...
# 18236            Grant Park           NaN     TRIANGLE     IL
# 18237           Spirit Lake           NaN         DISK     IA
# 18238           Eagle River           NaN          NaN     WI
# 18239           Eagle River           RED        LIGHT     WI
# 18240                  Ybor           NaN         OVAL     FL
#
#                   timee                 location
# 0        6/1/1930 22:00                Ithaca,NY
# 1       6/30/1930 20:00           Willingboro,NJ
# 2       2/15/1931 14:00               Holyoke,CO
# ...

# %% [markdown]
# # replace the space in columns with underscore

# %%
ufo.columns = ufo.columns.str.replace(" ","_")
ufo.columns
# Out:
# Index(['city', 'colour_report', 'shape_report', 'statee', 'timee', 'location'], dtype='object')

# %% [markdown]
# # removin a column from  a data set

# %%
ufo.drop('colour_report',axis = 1, inplace =  True)
# Out:
#                    city shape_report statee            timee  \
# 0                Ithaca     TRIANGLE     NY   6/1/1930 22:00
# 1           Willingboro        OTHER     NJ  6/30/1930 20:00
# 2               Holyoke         OVAL     CO  2/15/1931 14:00
# 3               Abilene         DISK     KS   6/1/1931 13:00
# 4  New York Worlds Fair        LIGHT     NY  4/18/1933 19:00
#
#                   location
# 0                Ithaca,NY
# 1           Willingboro,NJ
# 2               Holyoke,CO
# 3               Abilene,KS
# 4  New York Worlds Fair,NY

# %% [markdown]
# # removing more than one column

# %%
ufo.drop(["city",'timee'],axis = 1 , inplace = True)
ufo
# Out:
#       shape_report statee                 location
# 0         TRIANGLE     NY                Ithaca,NY
# 1            OTHER     NJ           Willingboro,NJ
# 2             OVAL     CO               Holyoke,CO
# 3             DISK     KS               Abilene,KS
# 4            LIGHT     NY  New York Worlds Fair,NY
# ...            ...    ...                      ...
# 18236     TRIANGLE     IL            Grant Park,IL
# 18237         DISK     IA           Spirit Lake,IA
# 18238          NaN     WI           Eagle River,WI
# 18239        LIGHT     WI           Eagle River,WI
# 18240         OVAL     FL                  Ybor,FL
#
# [18241 rows x 3 columns]

# %% [markdown]
# # removing row from a data frame

# %%
ufo.drop([0,1],axis = 0, inplace = True )
ufo
# Out:
#       shape_report statee                 location
# 2             OVAL     CO               Holyoke,CO
# 3             DISK     KS               Abilene,KS
# 4            LIGHT     NY  New York Worlds Fair,NY
# 5             DISK     ND           Valley City,ND
# 6           CIRCLE     CA           Crater Lake,CA
# ...            ...    ...                      ...
# 18236     TRIANGLE     IL            Grant Park,IL
# 18237         DISK     IA           Spirit Lake,IA
# 18238          NaN     WI           Eagle River,WI
# 18239        LIGHT     WI           Eagle River,WI
# 18240         OVAL     FL                  Ybor,FL
#
# [18239 rows x 3 columns]

# %% [markdown]
# # sort a data frame or a series

# %%
movies = pd.read_csv("http://bit.ly/imdbratings")
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.sort_values(["title",'duration'])
# Out:
#      star_rating                  title content_rating      genre  duration  \
# 542          7.8   (500) Days of Summer          PG-13     Comedy        95
# 5            8.9           12 Angry Men      NOT RATED      Drama        96
# 201          8.1       12 Years a Slave              R  Biography       134
# 698          7.6              127 Hours              R  Adventure        94
# 110          8.3  2001: A Space Odyssey              G    Mystery       160
# ..           ...                    ...            ...        ...       ...
# 955          7.4       Zero Dark Thirty              R      Drama       157
# 677          7.7                 Zodiac              R      Crime       157
# 615          7.7             Zombieland              R     Comedy        88
# 526          7.8                   Zulu        UNRATED      Drama       138
# 864          7.5                  [Rec]              R     Horror        78
#
#                                            actors_list
# ...

# %% [markdown]
# # filter  rows by a column value

# %%
is_long = movies.duration >= 200
is_long.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: duration, dtype: bool

# %%
movies[is_long]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
len(is_long)
# Out:
# 979

# %%
movies[movies.genre == "Crime"]
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 21           8.7               City of God              R  Crime       130
# ..           ...                       ...            ...    ...       ...
# 927          7.5                     Brick              R  Crime       110
# 931          7.4              Mean Streets              R  Crime       112
# 950          7.4                     Bound              R  Crime       108
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 978          7.4               Wall Street              R  Crime       126
#
#                                            actors_list
# ...

# %%
movies.loc[movies.duration >= 200,"genre"]
# Out:
# 2          Crime
# 7      Adventure
# 17         Drama
# 78         Crime
# 85     Adventure
# 142    Adventure
# 157        Drama
# 204    Adventure
# 445    Adventure
# 476        Drama
# 630    Biography
# 767       Action
# Name: genre, dtype: object

# %% [markdown]
# # multiple filter criteria

# %%
padam = pd.read_csv("http://bit.ly/imdbratings")

# %%
padam[(padam.duration >= 200) & (padam.genre == 'Drama')]
# Out:
#      star_rating               title content_rating  genre  duration  \
# 17           8.7       Seven Samurai        UNRATED  Drama       207
# 157          8.2  Gone with the Wind              G  Drama       238
# 476          7.8              Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
padam[(padam.duration >= 200) | (padam.genre == 'Drama')]               ## or condition
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 5            8.9                                   12 Angry Men
# 7            8.9  The Lord of the Rings: The Return of the King
# 9            8.9                                     Fight Club
# 13           8.8                                   Forrest Gump
# ..           ...                                            ...
# 958          7.4                             My Sister's Keeper
# 968          7.4                            The English Patient
# 970          7.4                                    Wonder Boys
# 972          7.4                                 Blue Valentine
# 973          7.4                          The Cider House Rules
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 5        NOT RATED      Drama        96
# 7            PG-13  Adventure       201
# ...

# %%
movies[movies.genre.isin(["Crime","Drama","Action"])]     ### three criteria in one using " isin "
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 970          7.4                                      Wonder Boys
# 972          7.4                                   Blue Valentine
# 973          7.4                            The Cider House Rules
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating   genre  duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# ...

# %%
padam[(padam.star_rating >= 8) & (padam.genre == 'Drama')]
# Out:
#      star_rating                            title content_rating  genre  \
# 5            8.9                     12 Angry Men      NOT RATED  Drama
# 9            8.9                       Fight Club              R  Drama
# 13           8.8                     Forrest Gump          PG-13  Drama
# 16           8.7  One Flew Over the Cuckoo's Nest              R  Drama
# 17           8.7                    Seven Samurai        UNRATED  Drama
# ..           ...                              ...            ...    ...
# 379          8.0              Edward Scissorhands          PG-13  Drama
# 387          8.0                  Midnight Cowboy              X  Drama
# 389          8.0                           Freaks        UNRATED  Drama
# 390          8.0            Letters from Iwo Jima              R  Drama
# 392          8.0                            Glory              R  Drama
#
#      duration                                        actors_list
# ...

# %% [markdown]
# # select series which are only numeric

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
import numpy as np

# %%
drinks.select_dtypes(include=[np.number]).dtypes
# Out:
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# dtype: object

# %% [markdown]
# # using string methods in pandas

# %%
hotels = pd.read_table("http://bit.ly/chiporder")
hotels.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
hotels[hotels.item_name.str.contains("Chicken")]
# Out:
#       order_id  quantity             item_name  \
# 4            2         2          Chicken Bowl
# 5            3         1          Chicken Bowl
# 11           6         1  Chicken Crispy Tacos
# 12           6         1    Chicken Soft Tacos
# 13           7         1          Chicken Bowl
# ...        ...       ...                   ...
# 4604      1828         1          Chicken Bowl
# 4615      1832         1    Chicken Soft Tacos
# 4619      1834         1    Chicken Salad Bowl
# 4620      1834         1    Chicken Salad Bowl
# 4621      1834         1    Chicken Salad Bowl
#
#                                      choice_description item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 11    [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $8.75
# 12    [Roasted Chili Corn Salsa, [Rice, Black Beans,...     $8.75
# ...

# %%
hotels.choice_description.str.replace("["," " ).str.replace("]"," ") #also as .str.replace('[\[\]]'," ")
# Out:
# 0                                                     NaN
# 1                                             Clementine
# 2                                                  Apple
# 3                                                     NaN
# 4        Tomatillo-Red Chili Salsa (Hot),  Black Beans...
#                               ...
# 4617     Fresh Tomato Salsa,  Rice, Black Beans, Sour ...
# 4618     Fresh Tomato Salsa,  Rice, Sour Cream, Cheese...
# 4619     Fresh Tomato Salsa,  Fajita Vegetables, Pinto...
# 4620     Fresh Tomato Salsa,  Fajita Vegetables, Lettu...
# 4621     Fresh Tomato Salsa,  Fajita Vegetables, Pinto...
# Name: choice_description, Length: 4622, dtype: object

# %% [markdown]
# # change the data type of a pandas series

# %%
kudimagan= pd.read_csv('http://bit.ly/drinksbycountry',dtype = {"beer_servings":float})
kudimagan.head(25)
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 0          Afghanistan            0.0                0              0
# 1              Albania           89.0              132             54
# 2              Algeria           25.0                0             14
# 3              Andorra          245.0              138            312
# 4               Angola          217.0               57             45
# 5    Antigua & Barbuda          102.0              128             45
# 6            Argentina          193.0               25            221
# 7              Armenia           21.0              179             11
# 8            Australia          261.0               72            212
# 9              Austria          279.0               75            191
# 10          Azerbaijan           21.0               46              5
# 11             Bahamas          122.0              176             51
# ...

# %%
hotels.dtypes                               #here itm price column is object we have to convert it into  int
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
hotels.item_price.str.replace("$", "").astype(float).mean()
# Out:
# 7.464335785374397

# %% [markdown]
# # using groupby in pandas series

# %%
kudimagan.beer_servings.mean()       # gonna mean beer serving by continent
# Out:
# 106.16062176165804

# %%
kudimagan.groupby('continent').beer_servings.mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
kudimagan[kudimagan.continent=="Africa"].beer_servings.max()
# Out:
# 376.0

# %%
kudimagan.groupby('continent').beer_servings.max()
# Out:
# continent
# Africa           376.0
# Asia             247.0
# Europe           361.0
# North America    285.0
# Oceania          306.0
# South America    333.0
# Name: beer_servings, dtype: float64

# %%
kudimagan.groupby('continent').beer_servings.agg(["count",'min','max','mean'])
# Out:
#                count   min    max        mean
# continent
# Africa            53   0.0  376.0   61.471698
# Asia              44   0.0  247.0   37.045455
# Europe            45   0.0  361.0  193.777778
# North America     23   1.0  285.0  145.434783
# Oceania           16   0.0  306.0   89.687500
# South America     12  93.0  333.0  175.083333

# %%
kudimagan[kudimagan.continent ==" Africa"].country
# Out:
# Series([], Name: country, dtype: object)

# %%
pd.crosstab(padam.genre,padam.content_rating)
# Out:
# content_rating  APPROVED   G  GP  NC-17  NOT RATED  PASSED  PG  PG-13    R  \
# genre
# Action                 3   1   1      0          4       1  11     44   67
# Adventure              3   2   0      0          5       1  21     23   17
# Animation              3  20   0      0          3       0  25      5    5
# Biography              1   2   1      0          1       0   6     29   36
# Comedy                 9   2   1      1         16       3  23     23   73
# Crime                  6   0   0      1          7       1   6      4   87
# Drama                 12   3   0      4         24       1  25     55  143
# Family                 0   1   0      0          0       0   1      0    0
# Fantasy                0   0   0      0          0       0   0      0    1
# Film-Noir              1   0   0      0          1       0   0      0    0
# History                0   0   0      0          0       0   0      0    0
# ...

# %% [markdown]
# # handling missing data with python

# %%
ufo.isnull().sum()                       # for identify how many missing data in each series
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
ufo[ufo.City.isnull()]
# Out:
#       City Colors Reported Shape Reported State              Time
# 21     NaN             NaN            NaN    LA    8/15/1943 0:00
# 22     NaN             NaN          LIGHT    LA    8/15/1943 0:00
# 204    NaN             NaN           DISK    CA   7/15/1952 12:30
# 241    NaN            BLUE           DISK    MT    7/4/1953 14:00
# 613    NaN             NaN           DISK    NV    7/1/1960 12:00
# 1877   NaN          YELLOW         CIRCLE    AZ    8/15/1969 1:00
# 2013   NaN             NaN            NaN    NH     8/1/1970 9:30
# 2546   NaN             NaN       FIREBALL    OH  10/25/1973 23:30
# 3123   NaN             RED       TRIANGLE    WV  11/25/1975 23:00
# 4736   NaN             NaN         SPHERE    CA   6/23/1982 23:00
# 5269   NaN             NaN            NaN    AZ   6/30/1985 21:30
# 6735   NaN             NaN      FORMATION    TX     4/1/1992 2:00
# 7208   NaN             NaN         CIRCLE    MI   10/4/1993 17:30
# ...

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
ufo.dropna(how="any").shape            # to drop a row if any value is missing
# Out:
# (2486, 5)

# %%
ufo.dropna(how="all").shape           # to drop arow where all the values are only missing
# Out:
# (18241, 5)

# %%
ufo.dropna(subset=["City","Shape Reported"],how = "any").shape     #to drop a row if any value i city and shape reported are missing
# Out:
# (15576, 5)

# %%
ufo['Shape Reported'].fillna(value ="VARIOUS",inplace = True)

# %%
ufo["Shape Reported"].value_counts(dropna = False)
# Out:
# VARIOUS      2977
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# FLARE           1
# HEXAGON         1
# PYRAMID         1
# DOME            1
# Name: Shape Reported, dtype: int64

# %%
kudimagan[kudimagan.continent =="Asia"]
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan            0.0                0              0
# 12                Bahrain           42.0               63              7
# 13             Bangladesh            0.0                0              0
# 19                 Bhutan           23.0                0              0
# 24                 Brunei           31.0                2              1
# 30               Cambodia           57.0               65              1
# 36                  China           79.0              192              8
# 46            North Korea            0.0                0              0
# 77                  India            9.0              114              0
# 78              Indonesia            5.0                1              0
# 79                   Iran            0.0                0              0
# 80                   Iraq            9.0                3              0
# ...

# %%
kudimagan.loc[77,"beer_servings"]
# Out:
# 9.0

# %%
kudimagan.set_index('continent',inplace = True)        # setting a column as a index
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# Asia                 0.0                0              0
# Europe              89.0              132             54
# Africa              25.0                0             14
# Europe             245.0              138            312
# Africa             217.0               57             45
#
#            total_litres_of_pure_alcohol
# continent
# Asia                                0.0
# Europe                              4.9
# Africa                              0.7
# Europe                             12.4
# Africa                              5.9

# %%
kudimagan.index.name= "continent"
kudimagan.reset_index(inplace = True)
kudimagan.head()                                                 #here reset the ndex into column 
                                                                #did some mistake here understand
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-f2bed2931266> in <module>
#       1 kudimagan.index.name= "continent"
# ----> 2 kudimagan.reset_index(inplace = True)
#       3 kudimagan.head()                                                 #here reset the ndex into column
#       4                                                                 #did some mistake here understand
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4602                 # to ndarray and maybe infer different dtype
#    4603                 level_values = _maybe_casted_values(lev, lab)
# -> 4604                 new_obj.insert(0, name, level_values)
#    4605
#    4606         new_obj.index = new_index
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
# ...

# %%
kudimagan.head()
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# continent
# 0          Afghanistan            0.0                0              0
# 1              Albania           89.0              132             54
# 2              Algeria           25.0                0             14
# 3              Andorra          245.0              138            312
# 4               Angola          217.0               57             45
#
#            total_litres_of_pure_alcohol continent
# continent
# 0                                   0.0      Asia
# 1                                   4.9    Europe
# 2                                   0.7    Africa
# 3                                  12.4    Europe
# 4                                   5.9    Africa

# %%
kudi = pd.read_csv("http://bit.ly/drinksbycountry")
kudi.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
kudi.set_index('country' , inplace = True)
kudi.head()                                         #see here a column country is changed into index
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
kudi.continent.value_counts().values  #here we found how many country on each continent by counting  the ontinent repetation
# Out:
# array([53, 45, 44, 23, 16, 12], dtype=int64)

# %%
kudi.continent.value_counts()["Africa"]
# Out:
# 53

# %%
kudi.continent.value_counts().sort_values()            #it sort on the values in ascending order
# Out:
# South America    12
# Oceania          16
# North America    23
# Asia             44
# Europe           45
# Africa           53
# Name: continent, dtype: int64

# %%
kudi.continent.value_counts().sort_index()                  #it sort on the basic of index
# Out:
# Africa           53
# Asia             44
# Europe           45
# North America    23
# Oceania          16
# South America    12
# Name: continent, dtype: int64

# %% [markdown]
# # creating a  new series in padas dataframe

# %%
people = pd.Series([30000,85000],index =["Albania","Andorra"],name = "population")
people
# Out:
# Albania    30000
# Andorra    85000
# Name: population, dtype: int64

# %%
kudi.beer_servings*people
# Out:
# Afghanistan           NaN
# Albania         2670000.0
# Algeria               NaN
# Andorra        20825000.0
# Angola                NaN
#                   ...
# Venezuela             NaN
# Vietnam               NaN
# Yemen                 NaN
# Zambia                NaN
# Zimbabwe              NaN
# Length: 193, dtype: float64

# %% [markdown]
# # connecting two dataset by concat

# %%
pd.concat([kudi,people],axis = 1).head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent  population
# Afghanistan                           0.0      Asia         NaN
# Albania                               4.9    Europe     30000.0
# Algeria                               0.7    Africa         NaN
# Andorra                              12.4    Europe     85000.0
# Angola                                5.9    Africa         NaN
